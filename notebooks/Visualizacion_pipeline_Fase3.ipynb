# %%
# %load_ext kedro.ipython
# Out:
# [09/09/24 19:14:19] INFO     Using                                                                  ]8;id=487681;file://C:\Users\matia\OneDrive\Escritorio\machine\.venv\lib\site-packages\kedro\framework\project\__init__.py\__init__.py]8;;\:]8;id=207473;file://C:\Users\matia\OneDrive\Escritorio\machine\.venv\lib\site-packages\kedro\framework\project\__init__.py#249\249]8;;\
#                              'C:\Users\matia\OneDrive\Escritorio\machine\.venv\lib\site-packages\ke
#                              dro\framework\project\rich_logging.yml' as logging configuration.
#                     INFO     Registered line magic '%reload_kedro'                                   ]8;id=701674;file://C:\Users\matia\OneDrive\Escritorio\machine\.venv\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=729616;file://C:\Users\matia\OneDrive\Escritorio\machine\.venv\lib\site-packages\kedro\ipython\__init__.py#58\58]8;;\
#                     INFO     Registered line magic '%load_node'                                      ]8;id=351402;file://C:\Users\matia\OneDrive\Escritorio\machine\.venv\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=369411;file://C:\Users\matia\OneDrive\Escritorio\machine\.venv\lib\site-packages\kedro\ipython\__init__.py#60\60]8;;\
#                     INFO     Resolved project path as:                                              ]8;id=380033;file://C:\Users\matia\OneDrive\Escritorio\machine\.venv\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=400933;file://C:\Users\matia\OneDrive\Escritorio\machine\.venv\lib\site-packages\kedro\ipython\__init__.py#175\175]8;;\
#                              C:\Users\matia\OneDrive\Escritorio\machine\Es_salud_mental.
#                              To set a different path, run '%reload_kedro <project_root>'
# [09/09/24 19:14:34] INFO     Kedro is sending anonymous usage data with the sole purpose of improving ]8;id=358396;file://C:\Users\matia\OneDrive\Escritorio\machine\.venv\lib\site-packages\kedro_telemetry\plugin.py\plugin.py]8;;\:]8;id=83235;file://C:\Users\matia\OneDrive\Escritorio\machine\.venv\lib\site-packages\kedro_telemetry\plugin.py#233\233]8;;\
#                              the product. No personal data or IP addresses are stored on our side. If
#                              you want to opt out, set the `KEDRO_DISABLE_TELEMETRY` or `DO_NOT_TRACK`
#                              environment variables, or create a `.telemetry` file in the current
#                              working directory with the contents `consent: false`. Read more at
#                              https://docs.kedro.org/en/stable/configuration/telemetry.html
# [09/09/24 19:14:35] INFO     Kedro project psicologia                                               ]8;id=482375;file://C:\Users\matia\OneDrive\Escritorio\machine\.venv\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=405539;file://C:\Users\matia\OneDrive\Escritorio\machine\.venv\lib\site-packages\kedro\ipython\__init__.py#141\141]8;;\
#                     INFO     Defined global variable 'context', 'session', 'catalog' and            ]8;id=33488;file://C:\Users\matia\OneDrive\Escritorio\machine\.venv\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=349632;file://C:\Users\matia\OneDrive\Escritorio\machine\.venv\lib\site-packages\kedro\ipython\__init__.py#142\142]8;;\
#                              'pipelines'

# %% [markdown]
# **Importamos las librerías para poder trabajar en el notebook.**

# %%
from kedro.framework.session import KedroSession
from kedro.framework.startup import bootstrap_project

# %% [markdown]
# **Mediante el pipeline creado llamamos a las funciones de nodes.py y pipeline.py para luego modificar el dataset y dejarlo listo para su uso.**

# %%
# Cargar el proyecto Kedro con el session
project_path = "C:/Users/matia/OneDrive/Escritorio/machine/Es_salud_mental"
bootstrap_project(project_path)

with KedroSession.create(project_path) as session:
    context = session.load_context()
    
    # Cargar los datasets generados por el pipeline
    nulos_data = context.catalog.load("nulos_data")
    imputed_data = context.catalog.load("imputed_data")
    mapped_data = context.catalog.load("mapped_data")

    # Visualizar los resultados
    print("Nulos Data:")
    display(nulos_data)

    print("Imputed Data:")
    display(imputed_data)

    print("Mapped Data:")
    display(mapped_data)
# Out:
# [09/09/24 19:14:36] INFO     Kedro is sending anonymous usage data with the sole purpose of improving ]8;id=39642;file://C:\Users\matia\OneDrive\Escritorio\machine\.venv\lib\site-packages\kedro_telemetry\plugin.py\plugin.py]8;;\:]8;id=908838;file://C:\Users\matia\OneDrive\Escritorio\machine\.venv\lib\site-packages\kedro_telemetry\plugin.py#233\233]8;;\
#                              the product. No personal data or IP addresses are stored on our side. If
#                              you want to opt out, set the `KEDRO_DISABLE_TELEMETRY` or `DO_NOT_TRACK`
#                              environment variables, or create a `.telemetry` file in the current
#                              working directory with the contents `consent: false`. Read more at
#                              https://docs.kedro.org/en/stable/configuration/telemetry.html
# [09/09/24 19:14:37] INFO     Loading data from nulos_data (CSVDataset)...                       ]8;id=271077;file://C:\Users\matia\OneDrive\Escritorio\machine\.venv\lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=157705;file://C:\Users\matia\OneDrive\Escritorio\machine\.venv\lib\site-packages\kedro\io\data_catalog.py#539\539]8;;\
#                     INFO     Kedro is sending anonymous usage data with the sole purpose of improving ]8;id=835859;file://C:\Users\matia\OneDrive\Escritorio\machine\.venv\lib\site-packages\kedro_telemetry\plugin.py\plugin.py]8;;\:]8;id=296824;file://C:\Users\matia\OneDrive\Escritorio\machine\.venv\lib\site-packages\kedro_telemetry\plugin.py#233\233]8;;\
#                              the product. No personal data or IP addresses are stored on our side. If
#                              you want to opt out, set the `KEDRO_DISABLE_TELEMETRY` or `DO_NOT_TRACK`
#                              environment variables, or create a `.telemetry` file in the current
#                              working directory with the contents `consent: false`. Read more at
#                              https://docs.kedro.org/en/stable/configuration/telemetry.html
#                     INFO     Loading data from imputed_data (CSVDataset)...                     ]8;id=408481;file://C:\Users\matia\OneDrive\Escritorio\machine\.venv\lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=580222;file://C:\Users\matia\OneDrive\Escritorio\machine\.venv\lib\site-packages\kedro\io\data_catalog.py#539\539]8;;\
# [09/09/24 19:14:39] INFO     Kedro is sending anonymous usage data with the sole purpose of improving ]8;id=806921;file://C:\Users\matia\OneDrive\Escritorio\machine\.venv\lib\site-packages\kedro_telemetry\plugin.py\plugin.py]8;;\:]8;id=486121;file://C:\Users\matia\OneDrive\Escritorio\machine\.venv\lib\site-packages\kedro_telemetry\plugin.py#233\233]8;;\
#                              the product. No personal data or IP addresses are stored on our side. If
#                              you want to opt out, set the `KEDRO_DISABLE_TELEMETRY` or `DO_NOT_TRACK`
#                              environment variables, or create a `.telemetry` file in the current
#                              working directory with the contents `consent: false`. Read more at
#                              https://docs.kedro.org/en/stable/configuration/telemetry.html
#                     INFO     Loading data from mapped_data (CSVDataset)...                      ]8;id=197217;file://C:\Users\matia\OneDrive\Escritorio\machine\.venv\lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=77874;file://C:\Users\matia\OneDrive\Escritorio\machine\.venv\lib\site-packages\kedro\io\data_catalog.py#539\539]8;;\
# Nulos Data:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#     Valores Nulos  Porcentaje Nulos
# 0               0          0.000000
# 1               0          0.000000
# 2               0          0.000000
# 3               0          0.000000
# 4            5202          1.779289
# 5               0          0.000000
# 6               0          0.000000
# 7               0          0.000000
# 8               0          0.000000
# 9               0          0.000000
# 10              0          0.000000
# 11              0          0.000000
# 12              0          0.000000
# 13              0          0.000000
# 14              0          0.000000
# 15              0          0.000000
# 16              0          0.000000
# Imputed Data:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                   Timestamp  Gender        Country Occupation self_employed  \
# 0       2014-08-27 11:29:31  Female  United States  Corporate            No
# 1       2014-08-27 11:31:50  Female  United States  Corporate            No
# 2       2014-08-27 11:32:39  Female  United States  Corporate            No
# 3       2014-08-27 11:37:59  Female  United States  Corporate            No
# 4       2014-08-27 11:43:36  Female  United States  Corporate            No
# ...                     ...     ...            ...        ...           ...
# 292359  2015-07-27 23:25:34    Male  United States   Business           Yes
# 292360  2015-08-17 09:38:35    Male   South Africa   Business            No
# 292361  2015-08-25 19:59:38    Male  United States   Business            No
# 292362  2015-09-26 01:07:35    Male  United States   Business            No
# 292363  2016-02-01 23:04:31    Male  United States   Business            No
#
#        family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# 0                  No       Yes    1-14 days            Yes             No
# 1                 Yes       Yes    1-14 days            Yes             No
# 2                 Yes       Yes    1-14 days            Yes             No
# 3                 Yes       Yes    1-14 days            Yes             No
# 4                 Yes       Yes    1-14 days            Yes             No
# ...               ...       ...          ...            ...            ...
# 292359            Yes       Yes   15-30 days             No          Maybe
# 292360            Yes       Yes   15-30 days             No          Maybe
# 292361            Yes        No   15-30 days             No          Maybe
# 292362            Yes       Yes   15-30 days             No          Maybe
# 292363            Yes       Yes   15-30 days             No          Maybe
#
#        Mental_Health_History Mood_Swings Coping_Struggles Work_Interest  \
# 0                        Yes      Medium               No            No
# 1                        Yes      Medium               No            No
# 2                        Yes      Medium               No            No
# 3                        Yes      Medium               No            No
# 4                        Yes      Medium               No            No
# ...                      ...         ...              ...           ...
# 292359                    No         Low              Yes            No
# 292360                    No         Low              Yes            No
# 292361                    No         Low              Yes            No
# 292362                    No         Low              Yes            No
# 292363                    No         Low              Yes            No
#
#        Social_Weakness mental_health_interview care_options
# 0                  Yes                      No     Not sure
# 1                  Yes                      No           No
# 2                  Yes                      No          Yes
# 3                  Yes                   Maybe          Yes
# 4                  Yes                      No          Yes
# ...                ...                     ...          ...
# 292359           Maybe                   Maybe     Not sure
# 292360           Maybe                      No          Yes
# 292361           Maybe                      No           No
# 292362           Maybe                      No          Yes
# 292363           Maybe                      No          Yes
#
# [292364 rows x 17 columns]
# Mapped Data:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                   Timestamp  Gender        Country Occupation  self_employed  \
# 0       2014-08-27 11:29:31  Female  United States  Corporate              0
# 1       2014-08-27 11:31:50  Female  United States  Corporate              0
# 2       2014-08-27 11:32:39  Female  United States  Corporate              0
# 3       2014-08-27 11:37:59  Female  United States  Corporate              0
# 4       2014-08-27 11:43:36  Female  United States  Corporate              0
# ...                     ...     ...            ...        ...            ...
# 292359  2015-07-27 23:25:34    Male  United States   Business              1
# 292360  2015-08-17 09:38:35    Male   South Africa   Business              0
# 292361  2015-08-25 19:59:38    Male  United States   Business              0
# 292362  2015-09-26 01:07:35    Male  United States   Business              0
# 292363  2016-02-01 23:04:31    Male  United States   Business              0
#
#         family_history  treatment Days_Indoors  Growing_Stress  \
# 0                    0          1    1-14 days               1
# 1                    1          1    1-14 days               1
# 2                    1          1    1-14 days               1
# 3                    1          1    1-14 days               1
# 4                    1          1    1-14 days               1
# ...                ...        ...          ...             ...
# 292359               1          1   15-30 days               0
# 292360               1          1   15-30 days               0
# 292361               1          0   15-30 days               0
# 292362               1          1   15-30 days               0
# 292363               1          1   15-30 days               0
#
#         Changes_Habits  Mental_Health_History Mood_Swings  Coping_Struggles  \
# 0                    0                      1      Medium                 0
# 1                    0                      1      Medium                 0
# 2                    0                      1      Medium                 0
# 3                    0                      1      Medium                 0
# 4                    0                      1      Medium                 0
# ...                ...                    ...         ...               ...
# 292359               2                      0         Low                 1
# 292360               2                      0         Low                 1
# 292361               2                      0         Low                 1
# 292362               2                      0         Low                 1
# 292363               2                      0         Low                 1
#
#         Work_Interest  Social_Weakness  mental_health_interview  care_options
# 0                   0                1                        0             2
# 1                   0                1                        0             0
# 2                   0                1                        0             1
# 3                   0                1                        2             1
# 4                   0                1                        0             1
# ...               ...              ...                      ...           ...
# 292359              0                2                        2             2
# 292360              0                2                        0             1
# 292361              0                2                        0             0
# 292362              0                2                        0             1
# 292363              0                2                        0             1
#
# [292364 rows x 17 columns]
