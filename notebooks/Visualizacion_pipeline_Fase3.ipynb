# %%
# %load_ext kedro.ipython
# Out:
# [10/07/24 19:01:15] INFO     Using                                                                  ]8;id=968419;file://C:\Users\jampu\OneDrive\Desktop\salud_mental\venv\Lib\site-packages\kedro\framework\project\__init__.py\__init__.py]8;;\:]8;id=341027;file://C:\Users\jampu\OneDrive\Desktop\salud_mental\venv\Lib\site-packages\kedro\framework\project\__init__.py#249\249]8;;\
#                              'C:\Users\jampu\OneDrive\Desktop\salud_mental\venv\Lib\site-packages\k
#                              edro\framework\project\rich_logging.yml' as logging configuration.
#                     INFO     Registered line magic '%reload_kedro'                                   ]8;id=984178;file://C:\Users\jampu\OneDrive\Desktop\salud_mental\venv\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=643871;file://C:\Users\jampu\OneDrive\Desktop\salud_mental\venv\Lib\site-packages\kedro\ipython\__init__.py#58\58]8;;\
# ...

# %% [markdown]
# **We import the libraries to be able to work on the notebook.**

# %%
from kedro.framework.session import KedroSession
from kedro.framework.startup import bootstrap_project
from kedro.framework.session import KedroSession
import pandas as pd

# %% [markdown]
# **Using the created pipeline we call the nodes.py and pipeline.py functions to then modify the dataset and leave it ready for use.**

# %%
# Cargar el proyecto Kedro con el session
project_path = "C:/Users/jampu/OneDrive/Desktop/salud_mental/psicologia"
bootstrap_project(project_path)

with KedroSession.create(project_path) as session:
    context = session.load_context()
    
    # Cargar los datasets generados por el pipeline
    nulos_data = context.catalog.load("nulos_data")
    imputed_data = context.catalog.load("imputed_data")
    mapped_data = context.catalog.load("mapped_data")

    # Visualizar los resultados
    print("Nulos Data:")
    display(nulos_data)

    print("Imputed Data:")
    display(imputed_data)

    print("Mapped Data:")
    display(mapped_data)
# Out:
# [10/07/24 19:02:26] INFO     Kedro is sending anonymous usage data with the sole purpose of improving ]8;id=30936;file://C:\Users\jampu\OneDrive\Desktop\salud_mental\venv\Lib\site-packages\kedro_telemetry\plugin.py\plugin.py]8;;\:]8;id=802486;file://C:\Users\jampu\OneDrive\Desktop\salud_mental\venv\Lib\site-packages\kedro_telemetry\plugin.py#233\233]8;;\
#                              the product. No personal data or IP addresses are stored on our side. If
#                              you want to opt out, set the `KEDRO_DISABLE_TELEMETRY` or `DO_NOT_TRACK`
#                              environment variables, or create a `.telemetry` file in the current
#                              working directory with the contents `consent: false`. Read more at
#                              https://docs.kedro.org/en/stable/configuration/telemetry.html
# ...

# %%
project_path = "C:/Users/jampu/OneDrive/Desktop/salud_mental/psicologia"
# Crear una sesión de Kedro y cargar el contexto del proyecto
with KedroSession.create(project_path) as session:
    context = session.load_context()
    
    # Cargar el dataset 'mapped_data' desde el catálogo de Kedro
    mapped_data = context.catalog.load("mapped_data")
    
    # Verificar si el dataset es un DataFrame de pandas
    if isinstance(mapped_data, pd.DataFrame):
        # Guardar el DataFrame como un archivo CSV
        mapped_data.to_csv("mapped_data.csv", index=False)
        print("El dataset 'mapped_data' se ha guardado como 'mapped_data.csv'.")
    else:
        print("El dataset 'mapped_data' no es un DataFrame de pandas.")
# Out:
# [10/07/24 19:03:17] INFO     Kedro is sending anonymous usage data with the sole purpose of improving ]8;id=971825;file://C:\Users\jampu\OneDrive\Desktop\salud_mental\venv\Lib\site-packages\kedro_telemetry\plugin.py\plugin.py]8;;\:]8;id=659484;file://C:\Users\jampu\OneDrive\Desktop\salud_mental\venv\Lib\site-packages\kedro_telemetry\plugin.py#233\233]8;;\
#                              the product. No personal data or IP addresses are stored on our side. If
#                              you want to opt out, set the `KEDRO_DISABLE_TELEMETRY` or `DO_NOT_TRACK`
#                              environment variables, or create a `.telemetry` file in the current
#                              working directory with the contents `consent: false`. Read more at
#                              https://docs.kedro.org/en/stable/configuration/telemetry.html
# ...
